# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import requests
from StringIO import StringIO
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def brightest(picture):
    """add up each pixel's color values 
    to approximate its overall luminance"""
    xsize, ysize = picture.size
    bx, by, max_val = 0, 0, 0
    for x in range(xsize):
        for y in range(ysize):
            r,g,b = pic.getpixel((x,y))
            if r+g+b > max_val:
                bx, by, max_val = x, y, r+g+b
    return (bx, by), max_val

# %%
from time import time
def elapsed(func, picture):
    """takes a function and a picture as arguments, 
    applies the function to the picture, and returns 
    the elapsed time along with whatever the function 
    itself returned."""    
    start = time()
    result = func(picture)
    return time() - start, result

# %%
def faster(picture):
    """This function, 'faster', uses 
    'picture.getdata' to unpack the 
    row-and-column representation of the 
    image to create a vector of pixels, 
    and then loops over that."""
    max_val = 0
    for (r,g,b) in picture.getdata():
        if r+g+b > max_val:
            max_val = r + g + b
    return max_val

# %%
def monochrome(picture, threshold):
    """loops over the pixels in the loaded image, 
    replacing the RGB values of each with either 
    black or white depending on whether its total 
    luminance is above or below some threshold 
    passed in by the user"""
    black = (0, 0, 0)
    white = (255, 255, 255)
    xsize, ysize = picture.size
    temp = picture.load()
    for x in range(xsize):
        for y in range(ysize):
            r,g,b = temp[x,y]
            if r+g+b >= threshold: 
                temp[x,y] = black
            else:
                temp[x,y] = white

# %%
BLACK = (0,0,0)
RED = (255,0,0)
#Modified to accept which fillfunction to use
def count(picture,fillfunc):
    """scan the image top to bottom and left to right using a nested loop.
    when black pixel is found, increment the count, then call the fill
    function to fill in all the pixels connected to that one."""
    xsize, ysize = picture.size
    temp = picture.load()
    result = 0
    for x in range(xsize):
        for y in range(ysize):
            if temp[x,y] == BLACK:
                result += 1
                fillfunc(temp,xsize,ysize,x,y)
    return result

# %%
def fill(picture, xsize, ysize, xstart, ystart):
    """keep a list of pixels that need to be looked at, 
    but haven't yet been filled in - a list of the (x,y) 
    coordinates of pixels that are neighbors of ones we have 
    already examined.  Keep looping until there's nothing 
    left in this list"""
    queue = [(xstart,ystart)]
    while queue:
        x,y,queue = queue[0][0], queue[0][1], queue[1:]
        if picture[x,y] == BLACK:
            picture[x,y] = RED
            if x > 0:
                queue.append((x-1,y))
            if x < (xsize-1):
                queue.append((x+1,y))
            if y > 0:
                queue.append((x, y-1))
            if y < (ysize-1):
                queue.append((x, y+1))

# %%
def recfill(picture, xsize, ysize, x, y):
    """each call to 'fillrec' takes care of one pixel, 
    then calls 'fillrec' again to take care of the neighbors"""
    if picture[x,y] != BLACK:
        return
    picture[x,y] = RED
    if x > 0:
        recfill(picture, xsize, ysize, x-1, y)
    if x < (xsize-1):
        recfill(picture, xsize, ysize, x+1, y)
    if y > 0:
        recfill(picture, xsize, ysize, x, y-1)
    if y < (ysize-1):
        recfill(picture, xsize, ysize, x, y+1)

# %%
#Image file names
imgnames = []
imgnames.append("http://imgsrc.hubblesite.org/hu/db/images/hs-2004-20-a-large_web.jpg")
imgnames.append("http://imgsrc.hubblesite.org/hu/db/images/hs-1993-13-a-large_web.jpg")
imgnames.append("http://imgsrc.hubblesite.org/hu/db/images/hs-1995-32-c-full_jpg.jpg")
imgnames.append("http://imgsrc.hubblesite.org/hu/db/images/hs-1993-13-a-large_web.jpg")
imgnames.append("http://imgsrc.hubblesite.org/hu/db/images/hs-2002-10-c-large_web.jpg")
imgnames.append("http://imgsrc.hubblesite.org/hu/db/images/hs-1999-30-b-full_jpg.jpg")

# %%
def fetchimg(name):
    response = requests.get(name)
    pic = Image.open(StringIO(response.content))
    return pic

#Useful for resetting images
def resetimg(imgname,threshold):
    '''re-fetch and monochrome
    an image
    '''
    picture = fetchimg(imgname)
    monochrome(picture,threshold)
    return picture

# %%
def fastfill(picture, xsize, ysize, xstart, ystart):
    """keep a list of pixels that need to be looked at, 
    but haven't yet been filled in - a list of the (x,y) 
    coordinates of pixels that are neighbors of ones we have 
    already examined.  Only look at neighbors if they haven't
    yet been filled in.  Keep looping until there's nothing 
    left in this list.
    Not much faster than fill"""
    queue = [(xstart,ystart)]
    while queue:
        x,y,queue = queue[0][0], queue[0][1], queue[1:]
        picture[x,y] = RED
        if x > 0 and picture[x-1,y] == BLACK:
            picture[x-1,y] = RED
            queue.append((x-1,y))
        if x < (xsize-1) and picture[x+1,y] == BLACK:
            picture[x+1,y] = RED
            queue.append((x+1,y))
        if y > 0 and picture[x,y-1] == BLACK:
            picture[x,y-1] = RED
            queue.append((x, y-1))
        if y < (ysize-1) and picture[x,y+1] == BLACK:
            picture[x,y+1] = RED
            queue.append((x, y+1))

# %%
#Need to modify elapsed as well.  count already modified above
def elapsed(func, fillfunc, picture):
    """takes a function and a picture as arguments, 
    applies the function to the picture, and returns 
    the elapsed time along with whatever the function 
    itself returned."""    
    start = time()
    result = func(picture,fillfunc)
    return time() - start, result

# %%
picture = resetimg(imgnames[0],600)
filltime = elapsed(count,fill,picture)

picture = resetimg(imgnames[0],600)
fastfilltime = elapsed(count,fastfill,picture)

picture = resetimg(imgnames[0],600)
recfilltime = elapsed(count,recfill,picture)

print "Fill: ",filltime
print "Fastfill: ",fastfilltime
print "Recfill: ",recfilltime
print "Max Time difference: ",max(filltime[0],fastfilltime[0],recfilltime[0]) - min(filltime[0],fastfilltime[0],recfilltime[0])
# Out:
# Fill:  (0.08599996566772461, 121)
# Fastfill:  (0.08500003814697266, 121)
# Recfill:  (0.07899999618530273, 121)
# Max Time difference:  0.00699996948242

# %%
for name in imgnames:
    picture = resetimg(name,600)
    numstars = count(picture,recfill)
    print "Image file: %s has %d stars with threshold = 600"%(name,numstars)
# Out:
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-2004-20-a-large_web.jpg has 121 stars with threshold = 600
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1993-13-a-large_web.jpg has 72 stars with threshold = 600
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1995-32-c-full_jpg.jpg has 82 stars with threshold = 600
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1993-13-a-large_web.jpg has 72 stars with threshold = 600
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-2002-10-c-large_web.jpg has 246 stars with threshold = 600
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1999-30-b-full_jpg.jpg has 320 stars with threshold = 600

# %%
for name in imgnames:
    picture = resetimg(name,500) #Different threshold value
    numstars = count(picture,fastfill)
    print "Image file: %s has %d stars with threshold = 500"%(name,numstars)
# Out:
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-2004-20-a-large_web.jpg has 210 stars with threshold = 500
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1993-13-a-large_web.jpg has 77 stars with threshold = 500
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1995-32-c-full_jpg.jpg has 117 stars with threshold = 500
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1993-13-a-large_web.jpg has 77 stars with threshold = 500
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-2002-10-c-large_web.jpg has 285 stars with threshold = 500
# Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1999-30-b-full_jpg.jpg has 355 stars with threshold = 500

# %%
def count2(picture,fillfunc):
    """scan the image top to bottom and left to right using a nested loop.
    when non-black pixel is found, increment the count, then call the fill
    function to fill in all the pixels connected to that one.  
    
    Return the count plus a list of star brightest pixel locations and value"""
    xsize, ysize = picture.size
    temp = picture.load()
    result = 0
    #a list of stars' max pixel locations and values
    starlist = []
    for x in range(xsize):
        for y in range(ysize):
            if temp[x,y] > BLACK:
                result += 1
                x,y,max_val = fillfunc(temp,xsize,ysize,x,y)
                starlist.append((x,y,max_val))
    return result,starlist

# %%
def fill2(picture, xsize, ysize, xstart, ystart):
    """keep a list of pixels that need to be looked at, 
    but haven't yet been filled in - a list of the (x,y) 
    coordinates of pixels that are neighbors of ones we have 
    already examined.  Keep looping until there's nothing 
    left in this list"""
    maxx,maxy,maxval = 0,0,0
    queue = [(xstart,ystart)]
    while queue:
        x,y,queue = queue[0][0], queue[0][1], queue[1:]
        r,g,b = picture[x,y]
        if (r+g+b > maxval):
            maxx,maxy,maxval = x,y,r+g+b
        if (r,g,b) > BLACK:
            picture[x,y] = BLACK
            if x > 0:
                queue.append((x-1,y))
            if x < (xsize-1):
                queue.append((x+1,y))
            if y > 0:
                queue.append((x, y-1))
            if y < (ysize-1):
                queue.append((x, y+1))
    return maxx,maxy,maxval

# %%
def imagecut(picture, threshold):
    """loops over the pixels in the loaded image, 
    replacing the RGB values of a pixel with black 
    (0,0,0) depending on whether its total 
    luminance is above or below some threshold 
    passed in by the user"""
    black = (0, 0, 0)
    xsize, ysize = picture.size
    temp = picture.load()
    for x in range(xsize):
        for y in range(ysize):
            r,g,b = temp[x,y]
            if r+g+b < threshold: 
                temp[x,y] = black

# %%
def resetimg2(imgname,threshold):
    '''re-fetch and cut image
    '''
    picture = fetchimg(imgname)
    imagecut(picture,threshold)
    return picture

# %%
def analyzepic(imgname,outname):
    threshold = 600
    fillfunc = 'fill2'
    picture = resetimg2(imgname,threshold)
    proctime, result = elapsed(count2,fill2,picture)
    #print proctime, result[0]
    stars = np.array(result[1])
    myheader = "\n Image file: %s\n Applied threshold: %d\n Algorithm used: %s \
                \n Processing time: %.6f (s)\n Star count: %d\n Location (x,y) and max luminance:\n" \
                %(imgname,threshold,fillfunc,proctime,result[0])
    np.savetxt(outname,stars,fmt=('%3i\t'*3),header=myheader)

# %%
analyzepic(imgnames[0],'Pleiades.txt')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-23-1b3ba2463785> in <module>()
# ----> 1 analyzepic(imgnames[0],'Pleiades.txt')
#
# <ipython-input-21-0a00789c66ab> in analyzepic(imgname, outname)
#       7     stars = np.array(result[1])
#       8     myheader = "\n Image file: %s\n Applied threshold: %d\n Algorithm used: %s                 \n Processing time: %.6f (s)\n Star count: %d\n Location (x,y) and max luminance:\n"                 %(imgname,threshold,fillfunc,proctime,result[0])
# ----> 9     np.savetxt(outname,stars,fmt=('%3i\t'*3),header=myheader)
#
# C:\Users\Cameron\Anaconda\lib\site-packages\numpy\lib\npyio.pyc in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments)
#    1004                 fh = open(fname, 'wb')
#    1005             else:
# -> 1006                 fh = open(fname, 'w')
#    1007     elif hasattr(fname, 'write'):
#    1008         fh = fname
#
# IOError: [Errno 22] invalid mode ('w') or filename: 'Pleiades.txt'

# %%
# !more Pleiades.txt
# Out:
# #
# #  Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-2004-20-a-large_web.jpg
# #  Applied threshold: 600
# #  Algorithm used: fill2
# #  Processing time: 0.078000 (s)
# #  Star count: 119
# #  Location (x,y) and max luminance:
# #
#  13     541     721
#  12     228     742
#  22     351     676
#  33     199     623
#  43       4     758
#  56     228     729
#  67     150     720
#  78     141     729
#  87     342     756
#  88     292     731
#  84     440     734
#  87     336     600
#  91       0     688
#  97     502     606
# 118     458     744
# 121     360     673
# 124     291     610
# 142       2     641
# 153     180     700
# 156     504     619
# 165     480     611
# 169     268     711
# 182     172     716
# 188     346     627
# 207     439     677
# 218     189     736
# 231     292     719
# 235     333     601
# 242     324     637
# 243     447     628
# 248     317     656
# 262     410     726
# 268     160     613
# 289     295     658
# 290     288     635
# 290     374     698
# 291     162     613
# 315     320     743
# 315     329     601
# 303      62     694
# 315     208     719
# 317     565     726
# 318      50     675
# 325     426     733
# 329      32     733
# 333     308     746
# 331     492     703
# 337     295     722
# 339     537     721
# 340     111     602
# 340     427     638
# 343     301     722
# 356     504     738
# 358     215     706
# 370     380     718
# 375       4     652
# 384      72     712
# 382     152     673
# 382     183     624
# 382     325     605
# 416     194     702
# 426     317     715
# 428     502     667
# 435     399     616
# 437     296     641
# 437     467     602
# 441     458     609
# 451     123     609
# 453     228     720
# 472     408     730
# 465      44     671
# 478     267     725
# 483     262     741
# 496     342     661
# 504     351     633
# 509      69     735
# 528      53     707
# 541     163     730
# 526     230     658
# 531     355     718
# 537     128     656
# 548     249     667
# 551     220     634
# 555     126     633
# 555     209     690
# 559      11     710
# 563     182     726
# 568     330     688
# 571     107     719
# 582     235     605
# 588     358     722
# 603     273     651
# 620     103     745
# 619     306     621
# 626      95     646
# 632     225     703
# 633     553     741
# 660     313     733
# 656     126     661
# 659     425     603
# 674     210     731
# 671     284     688
# 682     244     639
# 694      80     604
# 701     343     680
# 723      34     633
# 724     148     735
# 727     130     652
# 728     302     716
# 744     220     644
# 747     320     704
# 751     361     698
# 752     143     716
# 758     235     695
# 773      84     636
# 780      53     726
# 781     293     716
# 782     449     686
# 791     233     694

# %%
for name in imgnames:
    fileprefix = name.split('/')[6].split('.')[0]
    outname = fileprefix + '.txt'
    analyzepic(name,outname)
    # !more $outname
# Out:
# #
# #  Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-2004-20-a-large_web.jpg
# #  Applied threshold: 600
# #  Algorithm used: fill2
# #  Processing time: 0.077000 (s)
# #  Star count: 119
# #  Location (x,y) and max luminance:
# #
#  13     541     721
#  12     228     742
#  22     351     676
#  33     199     623
#  43       4     758
#  56     228     729
#  67     150     720
#  78     141     729
#  87     342     756
#  88     292     731
#  84     440     734
#  87     336     600
#  91       0     688
#  97     502     606
# 118     458     744
# 121     360     673
# 124     291     610
# 142       2     641
# 153     180     700
# 156     504     619
# 165     480     611
# 169     268     711
# 182     172     716
# 188     346     627
# 207     439     677
# 218     189     736
# 231     292     719
# 235     333     601
# 242     324     637
# 243     447     628
# 248     317     656
# 262     410     726
# 268     160     613
# 289     295     658
# 290     288     635
# 290     374     698
# 291     162     613
# 315     320     743
# 315     329     601
# 303      62     694
# 315     208     719
# 317     565     726
# 318      50     675
# 325     426     733
# 329      32     733
# 333     308     746
# 331     492     703
# 337     295     722
# 339     537     721
# 340     111     602
# 340     427     638
# 343     301     722
# 356     504     738
# 358     215     706
# 370     380     718
# 375       4     652
# 384      72     712
# 382     152     673
# 382     183     624
# 382     325     605
# 416     194     702
# 426     317     715
# 428     502     667
# 435     399     616
# 437     296     641
# 437     467     602
# 441     458     609
# 451     123     609
# 453     228     720
# 472     408     730
# 465      44     671
# 478     267     725
# 483     262     741
# 496     342     661
# 504     351     633
# 509      69     735
# 528      53     707
# 541     163     730
# 526     230     658
# 531     355     718
# 537     128     656
# 548     249     667
# 551     220     634
# 555     126     633
# 555     209     690
# 559      11     710
# 563     182     726
# 568     330     688
# 571     107     719
# 582     235     605
# 588     358     722
# 603     273     651
# 620     103     745
# 619     306     621
# 626      95     646
# 632     225     703
# 633     553     741
# 660     313     733
# 656     126     661
# 659     425     603
# 674     210     731
# 671     284     688
# 682     244     639
# 694      80     604
# 701     343     680
# 723      34     633
# 724     148     735
# 727     130     652
# 728     302     716
# 744     220     644
# 747     320     704
# 751     361     698
# 752     143     716
# 758     235     695
# 773      84     636
# 780      53     726
# 781     293     716
# 782     449     686
# 791     233     694
# #
# #  Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1993-13-a-large_web.jpg
# #  Applied threshold: 600
# #  Algorithm used: fill2
# #  Processing time: 0.093000 (s)
# #  Star count: 72
# #  Location (x,y) and max luminance:
# #
#   6     452     698
#  35     313     763
#  45     259     703
#  72     394     761
#  84     405     727
# 101     625     733
# 120     301     764
# 124     436     735
# 135     633     751
# 150     252     679
# 164     571     760
# 174     532     764
# 174     301     705
# 175     338     759
# 175     349     764
# 204     454     760
# 206     474     758
# 214      17     695
# 250     365     751
# 255     378     760
# 253     298     763
# 276     146     720
# 277     458     656
# 285     177     762
# 283     661     610
# 302     390     760
# 312     443     756
# 323     401     761
# 322     445     757
# 337     436     605
# 363     474     763
# 356     446     660
# 373     296     685
# 374     437     741
# 378     311     762
# 391     409     764
# 397     281     764
# 403     421     749
# 409     557     762
# 430     440     756
# 457     469     755
# 455     542     651
# 461     337     675
# 466     437     754
# 468     465     665
# 478     350     762
# 477     291     661
# 482      58     763
# 484     185     757
# 509     501     764
# 517     291     760
# 520     432     677
# 522     474     633
# 525     201     762
# 526     607     763
# 543     509     759
# 542     348     639
# 560     401     724
# 577     358     761
# 583     147     752
# 582     220     662
# 591     223     761
# 593     457     668
# 605     307     758
# 623     667     757
# 645     552     759
# 664     626     760
# 680     407     762
# 696     422     763
# 734     266     697
# 770     346     762
# 796     484     702
# #
# #  Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1995-32-c-full_jpg.jpg
# #  Applied threshold: 600
# #  Algorithm used: fill2
# #  Processing time: 0.045000 (s)
# #  Star count: 82
# #  Location (x,y) and max luminance:
# #
#   0      14     694
#   0      20     741
#   2     286     764
#   3     350     764
#   5     423     755
#   6     364     758
#   5     344     646
#  11      59     761
#  17     391     764
#  13     389     616
#  16     236     612
#  17      59     615
#  18     387     620
#  30     418     763
#  37     447     753
#  46      27     763
#  47     232     700
#  47     277     620
#  48     355     687
#  51     441     762
#  58     403     762
#  78      96     765
#  69      29     607
#  69     102     640
#  69     119     613
#  75     350     760
#  93     205     630
# 102     181     601
# 110     324     765
# 109       6     741
# 108      57     610
# 118     320     600
# 128     350     764
# 136     408     736
# 137     361     605
# 146       0     727
# 153       0     624
# 173      43     744
# 174     388     603
# 182      35     762
# 183     118     764
# 193     202     764
# 187     343     760
# 181     257     764
# 189     364     651
# 197     186     600
# 229     456     741
# 234     300     763
# 240     127     762
# 243     365     760
# 239     311     610
# 239     313     623
# 238     372     620
# 273     323     765
# 277      16     765
# 281      47     763
# 272     315     605
# 278     282     654
# 279     315     633
# 284     337     755
# 288      21     615
# 291     144     751
# 303     147     764
# 312      98     761
# 312     150     604
# 309     200     632
# 318     427     761
# 330     370     763
# 330     106     717
# 336     368     658
# 349     387     763
# 354     143     762
# 353     383     604
# 361       8     764
# 363     211     688
# 363     444     607
# 368     433     765
# 369       7     646
# 373     232     702
# 380     218     722
# 382      71     760
# 404     446     608
# #
# #  Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1993-13-a-large_web.jpg
# #  Applied threshold: 600
# #  Algorithm used: fill2
# #  Processing time: 0.092000 (s)
# #  Star count: 72
# #  Location (x,y) and max luminance:
# #
#   6     452     698
#  35     313     763
#  45     259     703
#  72     394     761
#  84     405     727
# 101     625     733
# 120     301     764
# 124     436     735
# 135     633     751
# 150     252     679
# 164     571     760
# 174     532     764
# 174     301     705
# 175     338     759
# 175     349     764
# 204     454     760
# 206     474     758
# 214      17     695
# 250     365     751
# 255     378     760
# 253     298     763
# 276     146     720
# 277     458     656
# 285     177     762
# 283     661     610
# 302     390     760
# 312     443     756
# 323     401     761
# 322     445     757
# 337     436     605
# 363     474     763
# 356     446     660
# 373     296     685
# 374     437     741
# 378     311     762
# 391     409     764
# 397     281     764
# 403     421     749
# 409     557     762
# 430     440     756
# 457     469     755
# 455     542     651
# 461     337     675
# 466     437     754
# 468     465     665
# 478     350     762
# 477     291     661
# 482      58     763
# 484     185     757
# 509     501     764
# 517     291     760
# 520     432     677
# 522     474     633
# 525     201     762
# 526     607     763
# 543     509     759
# 542     348     639
# 560     401     724
# 577     358     761
# 583     147     752
# 582     220     662
# 591     223     761
# 593     457     668
# 605     307     758
# 623     667     757
# 645     552     759
# 664     626     760
# 680     407     762
# 696     422     763
# 734     266     697
# 770     346     762
# 796     484     702
# #
# #  Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-2002-10-c-large_web.jpg
# #  Applied threshold: 600
# #  Algorithm used: fill2
# #  Processing time: 0.125000 (s)
# #  Star count: 242
# #  Location (x,y) and max luminance:
# #
#   3       3     750
#   2     286     763
#   1     574     765
#   3     770     761
#   7     179     752
#  12     310     763
#  29      99     625
#  30     562     600
#  33     611     684
#  40     775     722
#  44     759     760
#  51      62     747
#  60     657     753
#  69     269     714
#  70     518     624
#  74     156     760
#  79     540     758
#  83     155     740
#  91     561     765
# 611     369     762
# 617     566     760
# 617     149     603
# 622     437     747
# 624     759     612
# 628     298     723
# 631     209     760
# 631     197     667
# 642     210     742
# 641     337     699
# 642     734     633
# 645     272     748
# 654      80     672
# 654     693     615
# 656     288     763
# 667      21     754
# 673      96     765
# 675     709     691
# 677     345     760
# 677     784     656
# 681     463     758
# 685     199     760
# 703      33     764
# 701     433     748
# 701     772     728
# 701     227     742
# 709      45     757
# 710     572     745
# 719     189     759
# 720     688     617
# 726     302     756
# 724     168     644
# 728      32     760
# 734     318     764
# 736     548     760
# 745      69     763
# 745     348     738
# 745     478     663
# 744     556     763
# 751     465     752
# #
# #  Image file: http://imgsrc.hubblesite.org/hu/db/images/hs-1999-30-b-full_jpg.jpg
# #  Applied threshold: 600
# #  Algorithm used: fill2
# #  Processing time: 0.067000 (s)
# #  Star count: 312
# #  Location (x,y) and max luminance:
# #
#   1       6     724
#   1      30     762
#   1     131     705
#   1     282     765
#   9     280     765
#  10     358     764
#  10     192     709
#  12     289     765
#  14     388     765
#  13       1     765
#  13      91     742
#  16     159     727
#  16     135     765
#  20     427     765
#  19     258     657
#  27      94     765
#  31     326     712
#  32      80     765
#  34     353     765
#  40     251     765
#  50     379     704
#  55     140     761
#  57     385     765
#  61     238     764
#  64      81     607
#  64     281     765
#  65     368     765
#  68     148     765
#  72     345     764
#  74       4     762
#  77     437     727
#  81     255     700
#  87      81     765
#  87     427     721
#  89     359     729
#  89     279     621
#  96     369     765
#  99     338     720
# 100     216     765
# 102     147     762
# 106     429     763
# 106     420     656
# 112     140     706
# 115     109     764
# 119     501     724
# 120     105     764
# 120     224     765
# 122     328     765
# 124     398     765
# 120     364     708
# 122      93     765
# 122     180     765
# 122     186     663
# 121     231     688
# 121     474     604
# 122     250     765
# 124     161     617
# 125      20     730
# 128     161     765
# 131     331     765
# 135     122     763
# 135     283     765
# 135      99     765
# 136     172     764
# 138     229     765
# 139     184     765
# 140     246     764
# 142      10     707
# 145     262     765
# 146     266     763
# 147     398     764
# 149     109     765
# 151     240     638
# 152      63     711
# 155     185     650
# 156     225     765
# 156     270     764
# 157     311     765
# 160     160     765
# 159     145     622
# 160     126     660
# 161      49     630
# 165     257     749
# 168     214     764
# 169     233     765
# 169     271     765
# 170     148     764
# 171     264     765
# 171      37     668
# 174     386     692
# 175      73     765
# 176     261     665
# 181     178     764
# 182     294     688
# 181     378     632
# 183     134     765
# 183     198     764
# 184     228     765
# 189     401     763
# 189     139     609
# 191     206     765
# 192     212     765
# 191     292     765
# 190     119     765
# 191     184     765
# 195     168     748
# 198     239     765
# 201     128     764
# 202     226     762
# 200     276     765
# 203     119     765
# 203     131     745
# 206     175     765
# 206     211     765
# 207     313     763
# 204     195     765
# 206     123     765
# 205      72     762
# 208      15     650
# 208      83     607
# 210      94     765
# 211     162     765
# 211     195     765
# 212     254     765
# 209     203     764
# 211     150     719
# 215     232     765
# 214     241     765
